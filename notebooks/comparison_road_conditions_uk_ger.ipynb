# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df_collisions_uk = pd.read_csv('../data/processed/reduced_uk_dataset.csv',low_memory=False)
df_collisions_ger = pd.read_csv('../data/processed/modified_ger.csv',low_memory=False)

# %%
CITIZEN_GER = 83580000  #citizens in GER 2024
CITIZEN_UK = 69140000   #citizens in UK 2024

# %% [markdown]
# ### Absolute number of collision in both countries

# %%
collisions_ger = len(df_collisions_ger)
print("collisions ger:", collisions_ger)
collisions_uk = len(df_collisions_uk)
print("collisions uk:", collisions_uk)

collisions_ger_c = (len(df_collisions_ger)*100000)/CITIZEN_GER
print("collisions ger per 100.000 citizen:", collisions_ger_c)
collisions_uk_c = (len(df_collisions_uk)*100000)/CITIZEN_UK
print("collisions uk per 100.000 citizen:", collisions_uk_c)
# Out:
# collisions ger: 268519
# collisions uk: 100927
# collisions ger per 100.000 citizen: 321.27183536731275
# collisions uk per 100.000 citizen: 145.97483367081284

# %% [markdown]
# ### Deadly collisions at different weater conditions (normalized with population)

# %%
#slippery
#cycle collisions 
cycle_collisions_uk_s = ((df_collisions_uk['casualty_severity']==1) &(df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_collisions_uk_w = ((df_collisions_uk['casualty_severity']==1) &(df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_collisions_uk_d = ((df_collisions_uk['casualty_severity']==1) &(df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_collisions_ger_s = ((df_collisions_uk['casualty_severity']==1) &(df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_collisions_ger_w = ((df_collisions_uk['casualty_severity']==1) &(df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_collisions_ger_d = ((df_collisions_uk['casualty_severity']==1) &(df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 0)).sum()

#collisions with cycles and cars
cycle_car_collisions_uk_s = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_car_collisions_uk_w = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_car_collisions_uk_d = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()
cycle_car_collisions_ger_s = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_car_collisions_ger_w = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_car_collisions_ger_d = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# collisions with cycles and motorcycles
cycle_mcycle_collisions_uk_s = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_mcycle_collisions_uk_w = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_mcycle_collisions_uk_d = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_mcycle_collisions_ger_s = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_mcycle_collisions_ger_w = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_mcycle_collisions_ger_d = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# collisions with cycles and motorcycles
cycle_goodsv_collisions_uk_s = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_goodsv_collisions_uk_w = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_goodsv_collisions_uk_d = ((df_collisions_uk['casualty_severity']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_goodsv_collisions_ger_s = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_goodsv_collisions_ger_w = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_goodsv_collisions_ger_d = ((df_collisions_ger ['casualty_severity']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# %%
x_values1_s = np.array([cycle_collisions_ger_s,cycle_car_collisions_ger_s, cycle_mcycle_collisions_ger_s,cycle_goodsv_collisions_ger_s])
x_values1_w = np.array([cycle_collisions_ger_w,cycle_car_collisions_ger_w, cycle_mcycle_collisions_ger_w,cycle_goodsv_collisions_ger_w])
x_values1_d = np.array([cycle_collisions_ger_d,cycle_car_collisions_ger_d, cycle_mcycle_collisions_ger_d,cycle_goodsv_collisions_ger_d])

x_values2_s = np.array([cycle_car_collisions_uk_s,cycle_car_collisions_uk_s,cycle_mcycle_collisions_uk_s,cycle_goodsv_collisions_uk_s])
x_values2_w = np.array([cycle_car_collisions_uk_w,cycle_car_collisions_uk_w,cycle_mcycle_collisions_uk_w,cycle_goodsv_collisions_uk_w])
x_values2_d = np.array([cycle_car_collisions_uk_d,cycle_car_collisions_uk_d,cycle_mcycle_collisions_uk_d,cycle_goodsv_collisions_uk_d])


x_values1_s = (x_values1_s *100000)/ CITIZEN_GER
x_values1_w = (x_values1_w *100000)/ CITIZEN_GER
x_values1_d = (x_values1_d *100000)/ CITIZEN_GER
x_values2_s = (x_values2_s *100000)/ CITIZEN_UK
x_values2_w = (x_values2_w *100000)/ CITIZEN_UK
x_values2_d = (x_values2_d *100000)/ CITIZEN_UK

y_values_s = [min(x_values1_s), max(x_values1_s)]
plt.yscale('log')
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cars', 'motorcycles', 'goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.1

# Erstellen der Balkendiagramme
plt.bar(x - (width*2.5), x_values1_s, width, label='slippery,ger', color='black')
plt.bar(x - (width*1.5), x_values1_w, width, label='wet,ger', color="#F24D4D")
plt.bar(x - (width*0.5), x_values1_d, width, label='dry,ger', color='gold')

plt.bar(x + (width*0.5), x_values2_s, width, label='slippery,uk', color='blue')
plt.bar(x + (width*1.5), x_values2_w, width, label='wet,uk', color= 'red')
plt.bar(x + (width*2.5), x_values2_d, width, label='dry,uk', color='lightgrey')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('deaths of vehicle types depending on road surface conditions')
plt.xlabel('vehicle types')
plt.ylabel('collisions')
plt.legend()
plt.xticks(x, labels)
# save plot
plt.savefig('../results/plots_road_conditions/deaths_road_c_vehicle_types.png', bbox_inches='tight')

# %% [markdown]
# ### Collisions at different weater conditions (normalized with population)

# %%
#slippery
#cycle collisions 
cycle_collisions_uk_s = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_collisions_uk_w = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_collisions_ger_s = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_collisions_ger_w = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_collisions_ger_d = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 0)).sum()

#collisions with cycles and cars
cycle_car_collisions_uk_s = ((df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_car_collisions_uk_w = ((df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_car_collisions_uk_d = ((df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()
cycle_car_collisions_ger_s = ((df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_car_collisions_ger_w = ((df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_car_collisions_ger_d = ((df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# collisions with cycles and motorcycles
cycle_mcycle_collisions_uk_s = ((df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_mcycle_collisions_uk_w = ((df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_mcycle_collisions_uk_d = ((df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_mcycle_collisions_ger_s = ((df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_mcycle_collisions_ger_w = ((df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_mcycle_collisions_ger_d = ((df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# collisions with cycles and motorcycles
cycle_goodsv_collisions_uk_s = ((df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_goodsv_collisions_uk_w = ((df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_goodsv_collisions_uk_d = ((df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_goodsv_collisions_ger_s = ((df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_goodsv_collisions_ger_w = ((df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_goodsv_collisions_ger_d = ((df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# %%
x_values1_s = np.array([cycle_collisions_ger_s,cycle_car_collisions_ger_s, cycle_mcycle_collisions_ger_s,cycle_goodsv_collisions_ger_s])
x_values1_w = np.array([cycle_collisions_ger_w,cycle_car_collisions_ger_w, cycle_mcycle_collisions_ger_w,cycle_goodsv_collisions_ger_w])
x_values1_d = np.array([cycle_collisions_ger_d,cycle_car_collisions_ger_d, cycle_mcycle_collisions_ger_d,cycle_goodsv_collisions_ger_d])

x_values2_s = np.array([cycle_car_collisions_uk_s,cycle_car_collisions_uk_s,cycle_mcycle_collisions_uk_s,cycle_goodsv_collisions_uk_s])
x_values2_w = np.array([cycle_car_collisions_uk_w,cycle_car_collisions_uk_w,cycle_mcycle_collisions_uk_w,cycle_goodsv_collisions_uk_w])
x_values2_d = np.array([cycle_car_collisions_uk_d,cycle_car_collisions_uk_d,cycle_mcycle_collisions_uk_d,cycle_goodsv_collisions_uk_d])


x_values1_s = (x_values1_s *100000)/ CITIZEN_GER
x_values1_w = (x_values1_w *100000)/ CITIZEN_GER
x_values1_d = (x_values1_d *100000)/ CITIZEN_GER
x_values2_s = (x_values2_s *100000)/ CITIZEN_UK
x_values2_w = (x_values2_w *100000)/ CITIZEN_UK
x_values2_d = (x_values2_d *100000)/ CITIZEN_UK

y_values_s = [min(x_values1_s), max(x_values1_s)]
#plt.yscale('log')
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cars', 'motorcycles', 'goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.1

# Erstellen der Balkendiagramme
plt.bar(x - (width*2.5), x_values1_s, width, label='slippery,ger', color='black')
plt.bar(x - (width*1.5), x_values1_w, width, label='wet (ger)', color="#F24D4D")
plt.bar(x - (width*0.5), x_values1_d, width, label='dry (ger)', color='gold')

plt.bar(x + (width*0.5), x_values2_s, width, label='slippery (uk)', color='blue')
plt.bar(x + (width*1.5), x_values2_w, width, label='wet (uk)', color= 'lightgrey')
plt.bar(x + (width*2.5), x_values2_d, width, label='dry (uk)', color='red')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('collisions of vehicle types road surface conditions (per 100000)')
plt.xlabel('vehicle types')
plt.ylabel('collisions')
plt.legend()
plt.xticks(x, labels)
plt.savefig('../results/plots_road_conditions/road_c_vehicle_types_normalized.png', bbox_inches='tight')

# %%
#slippery
#cycle collisions 
cycle_collisions_uk_s_c = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 2)& (df_collisions_uk['casualty_severity']==1)).sum()
cycle_collisions_uk_w_c = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 1)& (df_collisions_uk['casualty_severity']==1)).sum()
cycle_collisions_uk_d_c = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 0)& (df_collisions_uk['casualty_severity']==1)).sum()

cycle_collisions_ger_s_c = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 2) & (df_collisions_ger['casualty_severity']==1)).sum()
cycle_collisions_ger_w_c = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 1) & (df_collisions_ger['casualty_severity']==1)).sum()
cycle_collisions_ger_d_c = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 0) & (df_collisions_ger['casualty_severity']==1)).sum()

# %%
x_values1 = [cycle_collisions_ger_s_c,cycle_collisions_ger_w_c ,cycle_collisions_ger_d_c]
print(x_values1)
x_values2 = [cycle_collisions_uk_s_c,cycle_collisions_uk_w_c,cycle_collisions_uk_d_c]
print(x_values2)

y_values = [min(x_values1), max(x_values1)]
#plt.yscale('log')

# Beispiel-Daten
labels = ['slipery','wet', 'dry']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.1

# Erstellen der Balkendiagramme
plt.bar(x - (width*2.5), x_values1, width, label='GER', color='blue')

plt.bar(x + (width*0.5), x_values2, width, label='UK', color='red')


# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('deadly cycles collisions  (road surface conditions)')
plt.xlabel('weather conditions')
plt.ylabel('collisions')
plt.legend()
plt.xticks(x, labels)
plt.yscale('log')
# Out:
# [np.int64(3), np.int64(60), np.int64(359)]
# [np.int64(0), np.int64(21), np.int64(64)]

# %%
df = pd.read_csv("../data/raw/dft-road-casualty-statistics-collision-2024.csv", low_memory=False)
#df

# %%
dry_deads = ((df['road_surface_conditions'] == 1) & (df['collision_severity'] == 1)).sum()
print(dry_deads)

frost_deads = (((df['road_surface_conditions'] == 3) | (df['road_surface_conditions'] == 4)) & (df['collision_severity'] == 1)).sum()
print(frost_deads)

unknown_deads = (((df['road_surface_conditions'] == -1) | (df['road_surface_conditions'] == 9)) & (df['collision_severity'] == 1)).sum()
print(unknown_deads)

wet_deads = (((df['road_surface_conditions'] == 2) | (df['road_surface_conditions'] == 5)| (df['road_surface_conditions'] == 6)| (df['road_surface_conditions'] == 7)) & (df['collision_severity'] == 1)).sum()
print(wet_deads)
# Out:
# 1042
# 9
# 2
# 449

# %% [markdown]
# ### deadly collisions for road surface conditions

# %%
#deadly collisions for road surface conditions
collisions_uk_s = ((df_collisions_uk['road_surface_conditions'] == 2)& (df_collisions_uk['casualty_severity']==1)).sum()
collisions_uk_w = ((df_collisions_uk['road_surface_conditions'] == 1)& (df_collisions_uk['casualty_severity']==1)).sum()
collisions_uk_d = ((df_collisions_uk['road_surface_conditions'] == 0)& (df_collisions_uk['casualty_severity']==1)).sum()

collisions_ger_s = ((df_collisions_ger['road_surface_conditions'] == 2) & (df_collisions_ger['casualty_severity']==1)).sum()
collisions_ger_w = ((df_collisions_ger['road_surface_conditions'] == 1) & (df_collisions_ger['casualty_severity']==1)).sum()
collisions_ger_d = ((df_collisions_ger['road_surface_conditions'] == 0) & (df_collisions_ger['casualty_severity']==1)).sum()

# %%
x_values1_road_conditions = np.array([collisions_ger_s,collisions_ger_w ,collisions_ger_d])
print(x_values1_road_conditions)
x_values2_road_conditions = np.array([collisions_uk_s,collisions_uk_w,collisions_uk_d])
print(x_values2_road_conditions)

y_values = [min(x_values1_road_conditions), max(x_values1_road_conditions)]
#plt.yscale('log')

# Beispiel-Daten
labels = ['slipery','wet', 'dry']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.1

# Erstellen der Balkendiagramme
plt.bar(x - (width*2.5), x_values1_road_conditions, width, label='GER', color='blue')


plt.bar(x + (width*0.5), x_values2_road_conditions, width, label='UK', color='red')


# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('deadly cycles collisions  (road surface conditions)')
plt.xlabel('groups')
plt.ylabel('collisions')
plt.legend()
plt.xticks(x, labels)
#plt.yscale('log')
# Out:
# [  34  594 1830]
# [   9  449 1042]
# ([<matplotlib.axis.XTick at 0x3049f11c0>,
# ...
#  [Text(0, 0, 'slipery'), Text(1, 0, 'wet'), Text(2, 0, 'dry')])

# %% [markdown]
# ### Deadly collisions at different weater conditions (normalized with population)

# %%
x_values_ger_road_conditions_norm = (x_values1_road_conditions *100000) / CITIZEN_GER
print(x_values_ger_road_conditions_norm)
x_values_uk_road_conditions_norm = (x_values2_road_conditions *100000) / CITIZEN_UK
print(x_values_uk_road_conditions_norm)

y_values = [min(x_values1), max(x_values1)]
#plt.yscale('log')

# Beispiel-Daten
labels = ['slipery','wet', 'dry']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.1

# Erstellen der Balkendiagramme
plt.bar(x - (width*2.5), x_values_ger_road_conditions_norm, width, label='GER', color='blue')
#plt.bar(x - (width*1.5), x_values1[1], width, label='wet,ger', color='blue')
#plt.bar(x - (width*0.5), x_values1[2], width, label='dry,ger', color='lightgrey')

plt.bar(x + (width*0.5), x_values_uk_road_conditions_norm, width, label='UK', color='red')
#plt.bar(x + (width*1.5), x_values2[1], width, label='wet,uk', color='red')
#plt.bar(x + (width*2.5), x_values2[2], width, label='dry,uk', color='orange')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('deadly  collisions  (road surface conditions) per 100000 citizen')
plt.xlabel('road conditions')
plt.ylabel('collisions')
plt.legend()
plt.xticks(x, labels)
plt.savefig('../results/plots_road_conditions/road_c_death.png', bbox_inches='tight') 
#plt.yscale('log')
# Out:
# [0.04067959 0.71069634 2.18951902]
# [0.01301707 0.649407   1.50708707]

# %%
#https://www.wetter.de/cms/jahreszeiten-astronomisch-meteorologisch-wann-beginnt-der-herbst-1832038.html

# def seasons(month):
#     if month in [3, 4, 5]:
#         return 'spring'
#     elif month in [6, 7, 8]:
#         return 'summer'
#     elif month in [9, 10, 11]:
#         return 'autumn'
#     else:
#         return 'winter'

# # season column
# df_collisions_ger['season'] = df_collisions_ger['month'].apply(seasons)
# df_collisions_uk['season'] = df_collisions_uk['month'].apply(seasons)

# %%
# df_collisions_ger.head(20)
# print(df_collisions_uk.columns)

# %% [markdown]
# ### Monthly differences

# %%
months_ger = []
months_uk = []
for i in range(1,13):
    collisions_ger_s = ((df_collisions_ger['month']== i) & (df_collisions_ger['road_surface_conditions'] == 2) & (df_collisions_ger['casualty_severity']==1)).sum()
    collisions_ger_w = ((df_collisions_ger['month']== i) & (df_collisions_ger['road_surface_conditions'] == 1) & (df_collisions_ger['casualty_severity']==1)).sum()
    collisions_ger_d = ((df_collisions_ger['month']== i) & (df_collisions_ger['road_surface_conditions'] == 0) & (df_collisions_ger['casualty_severity']==1)).sum()
    
    months_ger.append([collisions_ger_s,collisions_ger_w,collisions_ger_d])

    collisions_uk_s = ((df_collisions_uk['month']== i) & (df_collisions_uk['road_surface_conditions'] == 2)& (df_collisions_uk['casualty_severity']==1)).sum()
    collisions_uk_w = ((df_collisions_uk['month']== i) & (df_collisions_uk['road_surface_conditions'] == 1)& (df_collisions_uk['casualty_severity']==1)).sum()
    collisions_uk_d = ((df_collisions_uk['month']== i) & (df_collisions_uk['road_surface_conditions'] == 0)& (df_collisions_uk['casualty_severity']==1)).sum()

    months_uk.append([collisions_uk_s,collisions_uk_w,collisions_uk_d])

print(len(months_ger),len(months_uk))
#months
# Out:
# 12 12

# %%
different_months_ger = np.array(months_ger, dtype=float)
different_months_ger = (different_months_ger * 100000) / CITIZEN_GER
print(different_months_ger)

different_months_uk = np.array(months_uk, dtype=float)
different_months_uk = (different_months_uk *100000) / CITIZEN_UK
print(different_months_uk)
# Out:
# [[0.02273271 0.08614501 0.07896626]
#  [0.00119646 0.07178751 0.10169897]
#  [0.         0.04067959 0.16750419]
#  [0.00119646 0.04546542 0.19621919]
#  [0.         0.03828667 0.2189519 ]
#  [0.         0.03709021 0.25484566]
#  [0.         0.03709021 0.27398899]
#  [0.         0.028715   0.27997128]
#  [0.         0.03948313 0.25604212]
#  [0.         0.06221584 0.16750419]
#  [0.00358938 0.08853793 0.1124671 ]
#  [0.01196458 0.13519981 0.08135918]]
# [[0.00433902 0.09111947 0.08967313]
#  [0.         0.06653167 0.07376338]
#  [0.         0.05640729 0.11281458]
#  [0.         0.04194388 0.12872433]
#  [0.         0.03615852 0.13884871]
#  [0.         0.02314145 0.17500723]
#  [0.         0.03037316 0.15909748]
#  [0.         0.01446341 0.20393405]
#  [0.         0.05496095 0.10702922]
#  [0.         0.05496095 0.10847556]
#  [0.0072317  0.06508533 0.12149262]
#  [0.00144634 0.11426092 0.08822679]]

# %%
months = np.arange(1, 13) 
#values = np.random.rand(12)  # Zufallswerte für jeden Monat

# Subplots 3 rows , 1 Columns
fig, axes = plt.subplots(1, 3, subplot_kw={'projection': 'polar'}, figsize=(12, 9))

# ger, uk
colors = ['r', 'b']

subplot_titles = ['slippery','wet','dry']
# add first month to close plot
ticks = np.concatenate((months, [months[0]])) 
 

# Durchlauf durch die Subplots
for i, ax in enumerate(axes):
    # Daten für den aktuellen Subplot vorbereiten
    theta = np.linspace(0, 2 * np.pi, 12,endpoint=False)  # angle 12 month
    theta = np.concatenate((theta, [theta[0]])) # add first month to close plot
    g = different_months_ger[:,i] # Values for every month
    g = np.concatenate((g, [g[0]]))
    u = different_months_uk[:,i]
    u = np.concatenate((u, [u[0]]))
    
    # Polarplot erstellen
    ax.set_title(subplot_titles[i], pad=20)
    ax.plot(theta, g, marker='o', color=colors[0], label='ger')
    ax.plot(theta, u, marker='o', color=colors[1], label='uk')
    ax.fill(theta, g, alpha=0.1)  # 
    ax.fill(theta, u, alpha=0.1)
      
    ax.set_xticks(theta)  # x-axis-tics
    ax.set_xticklabels(ticks)  # month
    ax.set_ylim(0, 0.3)  # y-axis
    y_ticks = np.arange(0, 0.3, 0.1)
    ax.set_yticks(y_ticks) 
    if i == 1:  # first Plot
        ax.set_ylim(0, 0.2)  # y-axis
        y_ticks = np.arange(0, 0.2, 0.1)
        ax.set_yticks(y_ticks) 
    if i == 0:  # second plot
        ax.set_ylim(0, 0.03)  # y-axis
        y_ticks = np.arange(0, 0.03, 0.01)
        ax.set_yticks(y_ticks) 
# Layout anpassen und anzeigen
plt.tight_layout()
axes[2].legend(loc='upper right', fontsize='medium',bbox_to_anchor=(1, 1.3))
plt.suptitle('death per 100000 for different road surface conditions every month', fontsize = 20)
plt.tight_layout(rect=[0, 0.01, 1, 1.3])
plt.savefig('../results/plots_road_conditions/road_c_months_norm.png') 
plt.show()
