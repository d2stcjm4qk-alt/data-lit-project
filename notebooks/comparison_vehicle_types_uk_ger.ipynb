# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df_collisions_uk = pd.read_csv('../data/processed/reduced_uk_dataset.csv',low_memory=False)
df_collisions_ger = pd.read_csv('../data/processed/modified_ger.csv',low_memory=False)

# %%
CITIZEN_GER = 83580000  #citizens in GER 2024
CITIZEN_UK = 69140000   #citizens in UK 2024

# %% [markdown]
# ### Absolute number of collision in both countries

# %%
collisions_ger = len(df_collisions_ger)
print("collisions ger:", collisions_ger)
collisions_uk = len(df_collisions_uk)
print("collisions uk:", collisions_uk)

collisions_ger_c = (len(df_collisions_ger)*100000)/CITIZEN_GER
print("collisions ger per 100.000 citizen:", collisions_ger_c)
collisions_uk_c = (len(df_collisions_uk)*100000)/CITIZEN_UK
print("collisions uk per 100.000 citizen:", collisions_uk_c)
# Out:
# collisions ger: 268519
# collisions uk: 100927
# collisions ger per 100.000 citizen: 321.27183536731275
# collisions uk per 100.000 citizen: 145.97483367081284

# %% [markdown]
# ### Deadly collisions

# %% [markdown]
# ### Collisions between vehicle types

# %%
#cycle collisions 
cycle_collisions_uk = (df_collisions_uk['is_cyle']==1).sum()
cycle_collisions_ger = (df_collisions_ger['is_cyle']==1).sum()
print(cycle_collisions_ger, (df_collisions_uk['is_car']==1).sum())
#collisions with cycles and cars
cycle_car_collisions_uk = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_car']==1)).sum()
cycle_car_collisions_ger = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_car']==1)).sum()

# collisions with cycles and motorcycles
cycle_mcycle_collisions_uk = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_mcyle']==1)).sum()
cycle_mcycle_collisions_ger = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_mcyle']==1)).sum()

# collisions with cycles and motorcycles
cycle_goodsv_collisions_uk = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_goodsv']==1)).sum()
cycle_goodsv_collisions_ger = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_goodsv']==1)).sum()
# Out:
# 86543 91883

# %%
x_values1 = np.array([cycle_collisions_ger,cycle_car_collisions_ger, cycle_mcycle_collisions_ger,cycle_goodsv_collisions_ger])
x_values2 = np.array([cycle_car_collisions_uk,cycle_car_collisions_uk,cycle_mcycle_collisions_uk,cycle_goodsv_collisions_uk])


y_values = [min(x_values1), max(x_values1)]
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cycle & cars', 'cycle & motorcycles', 'cycle & goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.35

# Erstellen der Balkendiagramme
plt.bar(x - width/2, x_values1, width, label='Germany', color='blue')
plt.bar(x + width/2, x_values2, width, label='United Kingdom', color='red')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('Comparison cycles an other types')
plt.xlabel('groups')
plt.ylabel('collisions')
plt.xticks(x, labels)

# Legende hinzufügen
plt.legend()

# Plot anzeigen
plt.tight_layout()
plt.show()

# %%
x_values1 = np.array([cycle_collisions_ger,cycle_car_collisions_ger, cycle_mcycle_collisions_ger,cycle_goodsv_collisions_ger])
x_values2 = np.array([cycle_car_collisions_uk,cycle_car_collisions_uk,cycle_mcycle_collisions_uk,cycle_goodsv_collisions_uk])
x_values1_norm = (x_values1 *100000)/ CITIZEN_GER
x_values2_norm = (x_values2 *100000)/ CITIZEN_UK

y_values = [min(x_values1), max(x_values1)]
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cycle & cars', 'cycle & motorcycles', 'cycle & goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.35

# Erstellen der Balkendiagramme
plt.bar(x - width/2, x_values1_norm, width, label='Germany', color='blue')
plt.bar(x + width/2, x_values2_norm, width, label='United Kingdom', color='red')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('Comparison cycles an other types per 100000 persons')
plt.xlabel('groups')
plt.ylabel('collisions')
plt.xticks(x, labels)

# Legende hinzufügen
plt.legend()

# Plot anzeigen
plt.tight_layout()
plt.show()

# %%
#cycle collisions 
cycle_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['casualty_severity']==1)).sum()
cycle_collisions_ger_d = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['casualty_severity']==1)).sum()

#collisions with cycles and cars
cycle_car_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['casualty_severity']==1)).sum()
cycle_car_collisions_ger_d = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['casualty_severity']==1)).sum()

# collisions with cycles and motorcycles
cycle_mcycle_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['casualty_severity']==1)).sum()
cycle_mcycle_collisions_ger_d = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['casualty_severity']==1)).sum()

# collisions with cycles and motorcycles
cycle_goodsv_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['casualty_severity']==1)).sum()
cycle_goodsv_collisions_ger_d = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['casualty_severity']==1)).sum()

# %%
x_values1_d = [cycle_collisions_ger_d,cycle_car_collisions_ger_d, cycle_mcycle_collisions_ger_d,cycle_goodsv_collisions_ger_d]
x_values2_d = [cycle_car_collisions_uk_d,cycle_car_collisions_uk_d,cycle_mcycle_collisions_uk_d,cycle_goodsv_collisions_uk_d]
y_values_d = [min(x_values1), max(x_values1)]
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cycle & cars', 'cycle & motorcycles', 'cycle & goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.35

# Erstellen der Balkendiagramme
plt.bar(x - width/2, x_values1_d, width, label='Germany', color='blue')
plt.bar(x + width/2, x_values2_d, width, label='United Kingdom', color='red')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('Comparison cycles an other types (death)')
plt.xlabel('groups')
plt.ylabel('collisions')
plt.xticks(x, labels)

# Legende hinzufügen
plt.legend()

# Plot anzeigen
plt.tight_layout()
plt.show()

# %%
#cycle collisions 
cycle_collisions_uk_i = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['casualty_severity']==2)).sum()
cycle_collisions_ger_i = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['casualty_severity']==2)).sum()

#collisions with cycles and cars
cycle_car_collisions_uk_i = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['casualty_severity']==2)).sum()
cycle_car_collisions_ger_i = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['casualty_severity']==2)).sum()

# collisions with cycles and motorcycles
cycle_mcycle_collisions_uk_i = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['casualty_severity']==2)).sum()
cycle_mcycle_collisions_ger_i = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['casualty_severity']==2)).sum()

# collisions with cycles and motorcycles
cycle_goodsv_collisions_uk_i = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['casualty_severity']==2)).sum()
cycle_goodsv_collisions_ger_i = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['casualty_severity']==2)).sum()

# %%
x_values1_i = [cycle_collisions_ger_i,cycle_car_collisions_ger_i, cycle_mcycle_collisions_ger_i,cycle_goodsv_collisions_ger_i]
x_values2_i = [cycle_car_collisions_uk_i,cycle_car_collisions_uk_i,cycle_mcycle_collisions_uk_i,cycle_goodsv_collisions_uk_i]
y_values_i = [min(x_values1_i), max(x_values1_i)]
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cycle & cars', 'cycle & motorcycles', 'cycle & goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.35

# Erstellen der Balkendiagramme
plt.bar(x - width/2, x_values1_i, width, label='Germany', color='blue')
plt.bar(x + width/2, x_values2_i, width, label='United Kingdom', color='red')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('Comparison cycles an other types (severe injured)')
plt.xlabel('groups')
plt.ylabel('collisions')
plt.xticks(x, labels)

# Legende hinzufügen
plt.legend()

# Plot anzeigen
plt.tight_layout()
plt.show()

# %%
#cycle collisions 
cycle_collisions_uk_li = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['casualty_severity']==3)).sum()
cycle_collisions_ger_li = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['casualty_severity']==3)).sum()

#collisions with cycles and cars
cycle_car_collisions_uk_s = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['casualty_severity']==3)).sum()
cycle_car_collisions_ger_li = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['casualty_severity']==3)).sum()

# collisions with cycles and motorcycles
cycle_mcycle_collisions_uk_li = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['casualty_severity']==3)).sum()
cycle_mcycle_collisions_ger_li = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['casualty_severity']==3)).sum()

# collisions with cycles and motorcycles
cycle_goodsv_collisions_uk_li = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['casualty_severity']==3)).sum()
cycle_goodsv_collisions_ger_li = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['casualty_severity']==3)).sum()

# %%
x_values1_li = [cycle_collisions_ger_li,cycle_car_collisions_ger_li, cycle_mcycle_collisions_ger_li,cycle_goodsv_collisions_ger_li]
x_values2_li = [cycle_car_collisions_uk_s,cycle_car_collisions_uk_s,cycle_mcycle_collisions_uk_li,cycle_goodsv_collisions_uk_li]
y_values_s = [min(x_values1_li), max(x_values1_li)]
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cycle & cars', 'cycle & motorcycles', 'cycle & goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.35

# Erstellen der Balkendiagramme
plt.bar(x - width/2, x_values1_li, width, label='Germany', color='blue')
plt.bar(x + width/2, x_values2_li, width, label='United Kingdom', color='red')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('Comparison cycles an other types (light injured)')
plt.xlabel('groups')
plt.ylabel('collisions')
plt.yscale('log')
plt.xticks(x, labels)
# Out:
# ([<matplotlib.axis.XTick at 0x31292c110>,
# ...
#  [Text(0, 0, 'cycles'),
#   Text(1, 0, 'cycle & cars'),
#   Text(2, 0, 'cycle & motorcycles'),
#   Text(3, 0, 'cycle & goodv')])

# %% [markdown]
# ### Collisions between vehicle types at different weater conditions

# %%
#slippery
#cycle collisions 
cycle_collisions_uk_s = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_collisions_uk_w = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_collisions_ger_s = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_collisions_ger_w = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_collisions_ger_d = ((df_collisions_ger['is_cyle']==1) & (df_collisions_ger['road_surface_conditions'] == 0)).sum()

#collisions with cycles and cars
cycle_car_collisions_uk_s = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_car_collisions_uk_w = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_car_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_car']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()
cycle_car_collisions_ger_s = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_car_collisions_ger_w = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_car_collisions_ger_d = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_car']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# collisions with cycles and motorcycles
cycle_mcycle_collisions_uk_s = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_mcycle_collisions_uk_w = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_mcycle_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_mcyle']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_mcycle_collisions_ger_s = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_mcycle_collisions_ger_w = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_mcycle_collisions_ger_d = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_mcyle']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# collisions with cycles and motorcycles
cycle_goodsv_collisions_uk_s = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 2)).sum()
cycle_goodsv_collisions_uk_w = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 1)).sum()
cycle_goodsv_collisions_uk_d = ((df_collisions_uk['is_cyle']==1) & (df_collisions_uk['is_goodsv']==1)& (df_collisions_uk['road_surface_conditions'] == 0)).sum()

cycle_goodsv_collisions_ger_s = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 2)).sum()
cycle_goodsv_collisions_ger_w = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 1)).sum()
cycle_goodsv_collisions_ger_d = ((df_collisions_ger ['is_cyle']==1) & (df_collisions_ger['is_goodsv']==1)& (df_collisions_ger['road_surface_conditions'] == 0)).sum()

# %%
x_values1_s = [cycle_collisions_ger_s,cycle_car_collisions_ger_s, cycle_mcycle_collisions_ger_s,cycle_goodsv_collisions_ger_s]
x_values1_w = [cycle_collisions_ger_w,cycle_car_collisions_ger_w, cycle_mcycle_collisions_ger_w,cycle_goodsv_collisions_ger_w]
x_values1_d = [cycle_collisions_ger_d,cycle_car_collisions_ger_d, cycle_mcycle_collisions_ger_d,cycle_goodsv_collisions_ger_d]

x_values2_s = [cycle_car_collisions_uk_s,cycle_car_collisions_uk_s,cycle_mcycle_collisions_uk_s,cycle_goodsv_collisions_uk_s]
x_values2_w = [cycle_car_collisions_uk_w,cycle_car_collisions_uk_w,cycle_mcycle_collisions_uk_w,cycle_goodsv_collisions_uk_w]
x_values2_d = [cycle_car_collisions_uk_d,cycle_car_collisions_uk_d,cycle_mcycle_collisions_uk_d,cycle_goodsv_collisions_uk_d]


y_values_s = [min(x_values1_s), max(x_values1_s)]
plt.yscale('log')
#plt.plot(, y, marker='o', linestyle='-', color='b')

# Beispiel-Daten
labels = ['cycles', 'cycle & cars', 'cycle & motorcycles', 'cycle & goodv']

# Anzahl der Gruppen
x = np.arange(len(labels))

# Breite der Balken
width = 0.1

# Erstellen der Balkendiagramme
plt.bar(x - (width*2.5), x_values1_s, width, label='slippery,ger', color='lightblue')
plt.bar(x - (width*1.5), x_values1_w, width, label='wet,ger', color='blue')
plt.bar(x - (width*0.5), x_values1_d, width, label='dry,ger', color='lightgrey')

plt.bar(x + (width*0.5), x_values2_s, width, label='slippery,uk', color='#FF9999')
plt.bar(x + (width*1.5), x_values2_w, width, label='wet,uk', color='red')
plt.bar(x + (width*2.5), x_values2_d, width, label='dry,uk', color='orange')

# Hinzufügen von Titel und Achsenbeschriftungen
plt.title('Comparison cycles and other types (road surface conditions)')
plt.xlabel('groups')
plt.ylabel('collisions')
plt.legend()
plt.xticks(x, labels)
# Out:
# ([<matplotlib.axis.XTick at 0x302ad0d40>,
# ...
#  [Text(0, 0, 'cycles'),
#   Text(1, 0, 'cycle & cars'),
#   Text(2, 0, 'cycle & motorcycles'),
#   Text(3, 0, 'cycle & goodv')])
